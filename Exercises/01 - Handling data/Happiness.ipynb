# %% [markdown]
# ## Data from World Happiness Report
#
# The World Happiness Report is an annual publication of the United Nations Sustainable Development Solutions Network. It contains articles, and rankings of national happiness based on respondent ratings of their own lives, which the report also correlates with various life factors.
#
# In this notebook we will explore the happiness of different countries and the features associated.
# The datasets that we will use are available in *Data*: **happiness2020.pkl** and **countries_info.csv**.
#
# Although the features are self-explanatory, here a summary:
#
# **happiness2020.pkl**
# * country: *Name of the country*
# * happiness_score: *Happiness score*
# * social_support: *Social support (mitigation the effects of inequality)*
# * healthy_life_expectancy: *Healthy Life Expectancy*
# * freedom_of_choices: *Freedom to make life choices*
# * generosity: *Generosity (charity, volunteers)*
# * perception_of_corruption: *Corruption Perception*
# * world_region: *Area of the world of the country*
#
# **countries_info.csv**
# * country_name: *Name of the country*
# * area: *Area in sq mi*
# * population: *Number of people*
# * literacy: *Literacy percentage*

# %%
# !head Data/countries_info.csv
# Out:
# 'head' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
import pandas as pd
# %matplotlib inline

DATA_FOLDER = 'Data/'

HAPPINESS_DATASET = DATA_FOLDER+"happiness2020.pkl"
COUNTRIES_DATASET = DATA_FOLDER+"countries_info.csv"

#PICKLE TEMPORARLY!!!!!

# %% [markdown]
# ## Task 1: Load the data
#
# Load the 2 datasets in Pandas dataframes (called *happiness* and *countries*), and show the first rows.
#
#
# **Hint**: Use the correct reader and verify the data has the expected format.

# %%
# Write your code here
happiness = pd.read_pickle(HAPPINESS_DATASET)
happiness.head()
# Out:
#        country  happiness_score  social_support  healthy_life_expectancy  \
# 0  Afghanistan           2.5669        0.470367                52.590000
# 1      Albania           4.8827        0.671070                68.708138
# 2      Algeria           5.0051        0.803385                65.905174
# 3    Argentina           5.9747        0.900568                68.803802
# 4      Armenia           4.6768        0.757479                66.750656
#
#    freedom_of_choices  generosity  perception_of_corruption  \
# 0            0.396573   -0.096429                  0.933687
# 1            0.781994   -0.042309                  0.896304
# 2            0.466611   -0.121105                  0.735485
# 3            0.831132   -0.194914                  0.842010
# 4            0.712018   -0.138780                  0.773545
#
#                          world_region
# 0                          South Asia
# 1          Central and Eastern Europe
# 2        Middle East and North Africa
# 3         Latin America and Caribbean
# 4  Commonwealth of Independent States

# %%
country = happiness['country']
info = country.str.lower()
happiness.insert(0,'Country',info,True)
happiness
# Out:
#          Country      country  happiness_score  social_support  \
# 0    afghanistan  Afghanistan           2.5669        0.470367
# 1        albania      Albania           4.8827        0.671070
# 2        algeria      Algeria           5.0051        0.803385
# 3      argentina    Argentina           5.9747        0.900568
# 4        armenia      Armenia           4.6768        0.757479
# ..           ...          ...              ...             ...
# 130    venezuela    Venezuela           5.0532        0.890408
# 131      vietnam      Vietnam           5.3535        0.849987
# 132        yemen        Yemen           3.5274        0.817981
# 133       zambia       Zambia           3.7594        0.698824
# 134     zimbabwe     Zimbabwe           3.2992        0.763093
#
#      healthy_life_expectancy  freedom_of_choices  generosity  \
# 0                  52.590000            0.396573   -0.096429
# 1                  68.708138            0.781994   -0.042309
# 2                  65.905174            0.466611   -0.121105
# 3                  68.803802            0.831132   -0.194914
# 4                  66.750656            0.712018   -0.138780
# ..                       ...                 ...         ...
# 130                66.505341            0.623278   -0.169091
# 131                67.952736            0.939593   -0.094533
# 132                56.727283            0.599920   -0.157735
# 133                55.299377            0.806500    0.078037
# 134                55.617260            0.711458   -0.072064
#
#      perception_of_corruption                        world_region
# 0                    0.933687                          South Asia
# 1                    0.896304          Central and Eastern Europe
# 2                    0.735485        Middle East and North Africa
# 3                    0.842010         Latin America and Caribbean
# 4                    0.773545  Commonwealth of Independent States
# ..                        ...                                 ...
# 130                  0.837038         Latin America and Caribbean
# 131                  0.796421                      Southeast Asia
# 132                  0.800288        Middle East and North Africa
# 133                  0.801290                  Sub-Saharan Africa
# 134                  0.810237                  Sub-Saharan Africa
#
# [135 rows x 9 columns]

# %%
happiness = happiness.drop('country',axis=1)
happiness
# Out:
#          Country  happiness_score  social_support  healthy_life_expectancy  \
# 0    afghanistan           2.5669        0.470367                52.590000
# 1        albania           4.8827        0.671070                68.708138
# 2        algeria           5.0051        0.803385                65.905174
# 3      argentina           5.9747        0.900568                68.803802
# 4        armenia           4.6768        0.757479                66.750656
# ..           ...              ...             ...                      ...
# 130    venezuela           5.0532        0.890408                66.505341
# 131      vietnam           5.3535        0.849987                67.952736
# 132        yemen           3.5274        0.817981                56.727283
# 133       zambia           3.7594        0.698824                55.299377
# 134     zimbabwe           3.2992        0.763093                55.617260
#
#      freedom_of_choices  generosity  perception_of_corruption  \
# 0              0.396573   -0.096429                  0.933687
# 1              0.781994   -0.042309                  0.896304
# 2              0.466611   -0.121105                  0.735485
# 3              0.831132   -0.194914                  0.842010
# 4              0.712018   -0.138780                  0.773545
# ..                  ...         ...                       ...
# 130            0.623278   -0.169091                  0.837038
# 131            0.939593   -0.094533                  0.796421
# 132            0.599920   -0.157735                  0.800288
# 133            0.806500    0.078037                  0.801290
# 134            0.711458   -0.072064                  0.810237
#
#                            world_region
# 0                            South Asia
# 1            Central and Eastern Europe
# 2          Middle East and North Africa
# 3           Latin America and Caribbean
# 4    Commonwealth of Independent States
# ..                                  ...
# 130         Latin America and Caribbean
# 131                      Southeast Asia
# 132        Middle East and North Africa
# 133                  Sub-Saharan Africa
# 134                  Sub-Saharan Africa
#
# [135 rows x 8 columns]

# %%
countries = pd.read_csv(COUNTRIES_DATASET)
countries.head()
#countries.columns = ['country','area','population','literacy']
# Out:
#   country_name     area  population literacy
# 0  afghanistan   647500    31056997     36,0
# 1      albania    28748     3581655     86,5
# 2      algeria  2381740    32930091     70,0
# 3    argentina  2766890    39921833     97,1
# 4      armenia    29800     2976372     98,6

# %%
countries = countries.rename(columns = {'country_name' : 'Country'})

# %% [markdown]
# ## Task 2: Let's merge the data
#
# Create a dataframe called *country_features* by merging *happiness* and *countries*. A row of this dataframe must describe all the features that we have about a country.
#
# **Hint**: Verify that all the rows are in the final dataframe.

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     135 non-null    object
#  1   area        135 non-null    int64
#  2   population  135 non-null    int64
#  3   literacy    133 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 4.3+ KB

# %%
# Write your code here
country_features = pd.merge(happiness,countries,how = 'outer')
country_features.head()
# Out:
#        Country  happiness_score  social_support  healthy_life_expectancy  \
# 0  afghanistan           2.5669        0.470367                52.590000
# 1      albania           4.8827        0.671070                68.708138
# 2      algeria           5.0051        0.803385                65.905174
# 3    argentina           5.9747        0.900568                68.803802
# 4      armenia           4.6768        0.757479                66.750656
#
#    freedom_of_choices  generosity  perception_of_corruption  \
# 0            0.396573   -0.096429                  0.933687
# 1            0.781994   -0.042309                  0.896304
# 2            0.466611   -0.121105                  0.735485
# 3            0.831132   -0.194914                  0.842010
# 4            0.712018   -0.138780                  0.773545
#
#                          world_region     area  population literacy
# 0                          South Asia   647500    31056997     36,0
# 1          Central and Eastern Europe    28748     3581655     86,5
# 2        Middle East and North Africa  2381740    32930091     70,0
# 3         Latin America and Caribbean  2766890    39921833     97,1
# 4  Commonwealth of Independent States    29800     2976372     98,6

# %%
country_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   135 non-null    object
#  1   happiness_score           135 non-null    float64
#  2   social_support            135 non-null    float64
#  3   healthy_life_expectancy   135 non-null    float64
#  4   freedom_of_choices        135 non-null    float64
#  5   generosity                135 non-null    float64
#  6   perception_of_corruption  135 non-null    float64
#  7   world_region              135 non-null    object
#  8   area                      135 non-null    int64
#  9   population                135 non-null    int64
#  10  literacy                  133 non-null    object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 11.7+ KB

# %% [markdown]
# ## Task 3: Where are people happier?
#
# Print the top 10 countries based on their happiness score (higher is better).

# %%
# Write your code here
ranking = country_features.sort_values('happiness_score',ascending = False)
ranking.head(10)
# Out:
#          Country  happiness_score  social_support  healthy_life_expectancy  \
# 38       finland           7.8087        0.954330                71.900825
# 31       denmark           7.6456        0.955991                72.402504
# 115  switzerland           7.5599        0.942847                74.102448
# 50       iceland           7.5045        0.974670                73.000000
# 92        norway           7.4880        0.952487                73.200783
# 87   netherlands           7.4489        0.939139                72.300919
# 114       sweden           7.3535        0.926311                72.600769
# 88   new zealand           7.2996        0.949119                73.202629
# 6        austria           7.2942        0.928046                73.002502
# 72    luxembourg           7.2375        0.906912                72.599998
#
#      freedom_of_choices  generosity  perception_of_corruption  \
# 38             0.949172   -0.059482                  0.195445
# 31             0.951444    0.066202                  0.168489
# 115            0.921337    0.105911                  0.303728
# 50             0.948892    0.246944                  0.711710
# 92             0.955750    0.134533                  0.263218
# 87             0.908548    0.207612                  0.364717
# 114            0.939144    0.111615                  0.250880
# 88             0.936217    0.191598                  0.221139
# 6              0.899989    0.085429                  0.499955
# 72             0.905636   -0.004621                  0.367084
#
#               world_region    area  population literacy
# 38          Western Europe  338145     5231372    100,0
# 31          Western Europe   43094     5450661    100,0
# 115         Western Europe   41290     7523934     99,0
# 50          Western Europe  103000      299388     99,9
# 92          Western Europe  323802     4610820    100,0
# 87          Western Europe   41526    16491461     99,0
# 114         Western Europe  449964     9016596     99,0
# 88   North America and ANZ  268680     4076140     99,0
# 6           Western Europe   83870     8192880     98,0
# 72          Western Europe    2586      474413    100,0

# %% [markdown]
# We are interested to know in what world region people are happier.
#
# Create and print a dataframe with the (1) average happiness score and (2) the number of contries for each world region.
# Sort the result to show the happiness ranking.

# %%
#

region = ranking.groupby(['world_region'])['happiness_score'].agg(['mean','size','quantile','var','std'])
#region.sort_values(ascending = False)
#region.info()
country = region.sort_values(['mean'],ascending = False)
country
# Out:
#                                         mean  size  quantile       var  \
# world_region
# North America and ANZ               7.173525     4   7.22745  0.025492
# Western Europe                      6.967405    20   7.12910  0.388571
# Latin America and Caribbean         5.971280    20   6.05590  0.456383
# Central and Eastern Europe          5.891393    14   6.01110  0.310072
# Southeast Asia                      5.517788     8   5.36890  0.307260
# East Asia                           5.483633     3   5.45620  0.140029
# Commonwealth of Independent States  5.358342    12   5.54070  0.287861
# Middle East and North Africa        5.269306    16   5.04995  1.009351
# Sub-Saharan Africa                  4.393856    32   4.42735  0.415870
# South Asia                          4.355083     6   4.57990  1.288063
#
#                                          std
# world_region
# North America and ANZ               0.159661
# Western Europe                      0.623354
# Latin America and Caribbean         0.675561
# Central and Eastern Europe          0.556841
# Southeast Asia                      0.554310
# East Asia                           0.374205
# Commonwealth of Independent States  0.536527
# Middle East and North Africa        1.004665
# Sub-Saharan Africa                  0.644879
# South Asia                          1.134929

# %% [markdown]
# The first region has only a few countries! What are them and what is their score?

# %%
# Write your code here

# %% [markdown]
# ## Task 4: How literate is the world?
#
# Print the names of the countries with a level of literacy of 100%.
#
# For each country, print the name and the world region in the format: *{region name} - {country name} ({happiness score})*

# %%
# Write your code here

# %% [markdown]
# What is the global average?

# %%
# Write your code here

# %% [markdown]
# Calculate the proportion of countries with a literacy level below 50%. Print the value in percentage, formatted with 2 decimals.

# %%
# Write your code here

# %% [markdown]
# Print the raw number and the percentage of world population that is illiterate.

# %%
# Write your code here

# %% [markdown]
# ## Task 5: Population density
#
# Add to the dataframe a new field called *population_density* computed by dividing *population* by *area*.

# %%
# Write your code here

# %% [markdown]
# What is the happiness score of the 3 countries with the lowest population density?

# %%
# Write your code here

# %% [markdown]
# ## Task 6: Healty and happy?
#
# Plot in a scatter plot the happiness score (x) and healty life expectancy (y).

# %%
# Write your code here

# %% [markdown]
# Feel free to continue the exploration of the dataset! We'll release the solutions next week.
#
# ----
# Enjoy EPFL and be happy, next year Switzerland must be #1.
